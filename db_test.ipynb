# %%
import sqlite3
import pandas as pd




with sqlite3.connect("test.db") as con:
	print(con.execute("select name from sqlite_master where type='table';").fetchall())
	con.execute("create table if not exists test(x text, y int);")
	con.execute("INSERT INTO test VALUES('skibidi', 67);")
# Out:
# [('test',)]
